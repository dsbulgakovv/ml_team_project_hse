# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

users_path = '/content/drive/MyDrive/datasets/movies/users.csv'
items_path = '/content/drive/MyDrive/datasets/movies/items.csv'
interactions_path = '/content/drive/MyDrive/datasets/movies/interactions.csv'

# %%
users_df = pd.read_csv(users_path)
items_df = pd.read_csv(items_path)
interactions_df = pd.read_csv(interactions_path)

# %% [markdown]
# # Users

# %%
users_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840197 entries, 0 to 840196
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   840197 non-null  int64
#  1   age       826102 non-null  object
#  2   income    825421 non-null  object
#  3   sex       826366 non-null  object
#  4   kids_flg  840197 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 32.1+ MB

# %%
users_df.head()
# Out:
#    user_id        age        income sex  kids_flg
# 0   973171  age_25_34  income_60_90   М         1
# 1   962099  age_18_24  income_20_40   М         0
# 2  1047345  age_45_54  income_40_60   Ж         0
# 3   721985  age_45_54  income_20_40   Ж         0
# 4   704055  age_35_44  income_60_90   Ж         0

# %%
users_df.user_id.duplicated().sum()
# Out:
# 0

# %%
users_df.age.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
users_df.income.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
users_df.sex.value_counts().plot(kind='bar', title='Количество пользователей разного пола')
# Out:
# <Axes: title={'center': 'Количество пользователей разного пола'}>

# %%
users_df.kids_flg.value_counts().plot(kind='bar', title='Количество пользователй по наличию детей')
# Out:
# <Axes: title={'center': 'Количество пользователй по наличию детей'}>

# %%
users_heatmap = users_df.copy(deep=True)
users_heatmap.dropna(inplace=True)
users_heatmap = users_heatmap.loc[:, ['age', 'income', 'sex', 'kids_flg']]
users_heatmap.replace(
    {'age_18_24': 1, 'age_25_34': 2, 'age_35_44': 3, 'age_45_54': 4, 'age_55_64':5, 'age_65_inf':6,
     'income_0_20': 1, 'income_20_40': 2, 'income_40_60': 3, 'income_60_90': 4, 'income_90_150':5, 'income_150_inf':6,
     'Ж': 0, 'М': 1}, inplace=True
)

sns.heatmap(users_heatmap.corr(), annot=True, )
# Out:
# <Axes: >

# %% [markdown]
# # Items

# %%
items_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15963 entries, 0 to 15962
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   item_id       15963 non-null  int64
#  1   content_type  15963 non-null  object
#  2   title         15963 non-null  object
#  3   title_orig    11218 non-null  object
#  4   release_year  15865 non-null  float64
#  5   genres        15963 non-null  object
#  6   countries     15926 non-null  object
#  7   for_kids      566 non-null    float64
#  8   age_rating    15961 non-null  float64
#  9   studios       1065 non-null   object
#  10  directors     14454 non-null  object
#  11  actors        13344 non-null  object
#  12  description   15961 non-null  object
#  13  keywords      15540 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.7+ MB

# %%
items_df.head(3)
# Out:
#    item_id content_type             title      title_orig  release_year  \
# 0    10711         film    Поговори с ней  Hable con ella        2002.0
# 1     2508         film       Голые перцы    Search Party        2014.0
# 2    10716         film  Тактическая сила  Tactical Force        2011.0
#
#                                              genres countries  for_kids  \
# 0           драмы, зарубежные, детективы, мелодрамы   Испания       NaN
# 1                  зарубежные, приключения, комедии       США       NaN
# 2  криминал, зарубежные, триллеры, боевики, комедии    Канада       NaN
#
#    age_rating studios         directors  \
# 0        16.0     NaN  Педро Альмодовар
# 1        16.0     NaN    Скот Армстронг
# 2        16.0     NaN  Адам П. Калтраро
#
#                                               actors  \
# 0  Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1  Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2  Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
#
#                                          description  \
# 0  Мелодрама легендарного Педро Альмодовара «Пого...
# 1  Уморительная современная комедия на популярную...
# 2  Профессиональный рестлер Стив Остин («Все или ...
#
#                                             keywords
# 0  Поговори, ней, 2002, Испания, друзья, любовь, ...
# 1  Голые, перцы, 2014, США, друзья, свадьбы, прео...
# 2  Тактическая, сила, 2011, Канада, бандиты, ганг...

# %%
items_df.loc[:, [ 'title', 'title_orig', 'release_year', 'directors']].duplicated().sum()
# Out:
# 20

# %%
items_df[items_df.loc[:, ['title', 'title_orig', 'release_year', 'directors']].duplicated()].head()
# Out:
#       item_id content_type                          title  \
# 3635     2143       series    Чебурашка. Секрет праздника
# 4029     7725         film  Концерт группы Помпея/Pompeya
# 4222    14168       series               Концерт SIROTKIN
# 4728     8982       series           Концерт Мумий Тролль
# 5552    12722         film          Концерт ЛИЗЕР / LIZER
#
#                            title_orig  release_year  \
# 3635                              NaN        2020.0
# 4029  Kontsert gruppy Pompeya/Pompeya        2020.0
# 4222                Kontsert SIROTKIN        2020.0
# 4728            Kontsert Mumiy Troll'        2020.0
# 5552           Kontsert LIZER / LIZER        2020.0
#
#                                            genres countries  for_kids  \
# 3635  семейное, мультфильмы, приключения, комедии    Россия       1.0
# 4029                         концерт, музыкальные    Россия       NaN
# 4222                                  музыкальные    Россия       NaN
# 4728                                  музыкальные    Россия       NaN
# 5552                         концерт, музыкальные    Россия       NaN
#
#       age_rating studios            directors  \
# 3635         0.0     NaN         Дарина Шмидт
# 4029        12.0     NaN  Глова Роман Юрьевич
# 4222        12.0     NaN  Глова Роман Юрьевич
# 4728        12.0     NaN  Глова Роман Юрьевич
# 5552        12.0     NaN  Глова Роман Юрьевич
#
#                                                  actors  \
# 3635  Анжелика Варум, Леонид Ярмольник, Диомид Виног...
# 4029      Даниил Брод, Денис Агафонов, Дмитрий Винников
# 4222                                                NaN
# 4728  Илья Лагутенко, Олег Пунгин, Александр Холенко...
# 5552                                                NaN
#
#                                             description  \
# 3635  Празднование Нового Года для Чебурашки и Гены ...
# 4029  МТС «Карантинники» — это домашние акустические...
# 4222  МТС «Карантинники» — это домашние акустические...
# 4728  МТС «Карантинники» — это домашние акустические...
# 5552  МТС «Карантинники» — это домашние акустические...
#
#                                             keywords
# 3635      Чебурашка, Секрет, праздника, 2020, Россия
# 4029  2020, россия, концерт, группы, помпея, pompeya
# 4222                                             NaN
# 4728                                             NaN
# 5552             2020, россия, концерт, лизер, lizer

# %%
items_df.content_type.value_counts().plot(kind='bar', title='Количество фильмов и сериалов')
# Out:
# <Axes: title={'center': 'Количество фильмов и сериалов'}>

# %%
items_df.countries.value_counts()[:10]
# Out:
# Россия              4237
# США                 4090
# СССР                1401
# Франция             1158
# Великобритания       718
# Украина              340
# Италия               256
# Канада               233
# Республика Корея     230
# Испания              192
# Name: countries, dtype: int64

# %%
items_df.age_rating.hist()
# Out:
# <Axes: >

# %%
items_df.directors.value_counts()[:10]
# Out:
# Оливье Шиабоду         511
# Денис Франческо         49
# Глова Роман Юрьевич     36
# Сергей Зарев            29
# Альфред Хичкок          28
# Бад Фокс                27
# Бернар Геррини          26
# Стивен Спилберг         25
# Андрей Селиванов        22
# Эльдар Рязанов          19
# Name: directors, dtype: int64

# %% [markdown]
# #Interactions

# %%
interactions_df.last_watch_dt = pd.to_datetime(interactions_df.last_watch_dt)

# %%
interactions_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5476251 entries, 0 to 5476250
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   user_id        5476251 non-null  int64
#  1   item_id        5476251 non-null  int64
#  2   last_watch_dt  5476251 non-null  datetime64[ns]
#  3   total_dur      5476251 non-null  int64
#  4   watched_pct    5475423 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 208.9 MB

# %%
interactions_df.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct
# 0   176549     9506    2021-05-11       4250         72.0
# 1   699317     1659    2021-05-29       8317        100.0
# 2   656683     7107    2021-05-09         10          0.0
# 3   864613     7638    2021-07-05      14483        100.0
# 4   964868     9506    2021-04-30       6725        100.0

# %%
print(f'Number of unique users with interactions: {interactions_df.user_id.nunique()}')
print(f'Number of unique movies/series with interactions: {interactions_df.item_id.nunique()}')
# Out:
# Number of unique users with interactions: 962179
# Number of unique movies/series with interactions: 15706

# %%
print(f'Interactions time range: {interactions_df.last_watch_dt.min()} to {interactions_df.last_watch_dt.max()}')
# Out:
# Interactions time range: 2021-03-13 00:00:00 to 2021-08-22 00:00:00

# %%
np.log(interactions_df.groupby('item_id').agg('count').user_id.value_counts()).hist() # Распределение количества взаимодейсвий у фильмов
# Out:
# <Axes: >

# %%
interactions_df.watched_pct.hist()
# Out:
# <Axes: >

# %%
interactions_df['last_watch_dt'].hist(bins=50)
# Out:
# <Axes: >

# %%
interactions_df.groupby('last_watch_dt').agg('sum')
# Out:
#                    user_id    item_id  total_dur  watched_pct
# last_watch_dt
# 2021-03-13      8860532574  136918221  100239331     838641.0
# 2021-03-14      8537392016  130610123  103643545     832822.0
# 2021-03-15      6788842992  102901372   78701288     626049.0
# 2021-03-16      6968641712  106776443   82689161     636801.0
# 2021-03-17      6942297660  110651311   81305757     643960.0
# ...                    ...        ...        ...          ...
# 2021-08-18     31375844887  483901778  394018899    2271152.0
# 2021-08-19     32035160436  496207222  420957423    2306064.0
# 2021-08-20     33049704790  508069263  405775383    2343252.0
# 2021-08-21     37934079905  589052658  447459894    2637803.0
# 2021-08-22     38871393069  606212745  476974016    2830610.0
#
# [163 rows x 4 columns]

# %% [markdown]
# #Looking for insights

# %%
users_interactions = interactions_df.merge(users_df, on='user_id', how='inner')
users_interactions.dropna(inplace=True)

# %%
sex_interactions = users_interactions.groupby(['last_watch_dt', 'sex']).agg({'user_id': 'count', 'total_dur': 'sum'}).reset_index().sort_values('last_watch_dt')
sex_interactions
# Out:
#     last_watch_dt sex  user_id  total_dur
# 0      2021-03-13   Ж     6042   39335564
# 1      2021-03-13   М     7462   44111423
# 2      2021-03-14   Ж     5746   36459352
# 3      2021-03-14   М     7472   47441959
# 4      2021-03-15   Ж     4501   28400325
# ..            ...  ..      ...        ...
# 321    2021-08-20   М    23084  124732535
# 322    2021-08-21   Ж    26293  175992553
# 323    2021-08-21   М    26458  142937750
# 324    2021-08-22   Ж    26544  179195460
# 325    2021-08-22   М    27412  154182996
#
# [326 rows x 4 columns]

# %%
sns.lineplot(data=sex_interactions.pivot(index="last_watch_dt", columns="sex", values="user_id"));

# %%
sns.lineplot(data=sex_interactions.pivot(index="last_watch_dt", columns="sex", values="total_dur"));

# %%
print(f'{len(set(users_df.user_id.values)^set(interactions_df.user_id.values))} пользователей, которые нет в 1 из таблиц users/unteractions')
# Out:
# 313800 пользователей, которые нет в 1 из таблиц users/unteractions

# %%
genres = []
for item_genre in items_df.genres.values:
  genres.extend(item_genre.split(', '))
genres = set(genres)

# %%
users_movie_interactions = users_interactions.merge(items_df, on='item_id', how='inner')
users_movie_interactions[list(genres)] = 0

def set_genre(x):
  for genre in x['genres'].split(', '):
    x[genre] = 1
  return x

def norm_by_amout(x):
  x[3:] = x[3:]/(users_df[(users_df['age']==x['age']) & (users_df['income']==x['income']) & (users_df['sex']==x['sex'])].count()[0])
  return x

users_movie_interactions = users_movie_interactions.apply(set_genre, axis = 1)
user_genre = users_movie_interactions.groupby(['age', 'income', 'sex']).agg({i:'sum' for i in genres}).reset_index() # Какие жанры смотрят люди из разных категорий
user_genre = user_genre.apply(norm_by_amout, axis=1) # нормируем на количество пользователей в каждой категории
# Out:
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0
# <ipython-input-34-e5003749a5e7>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   users_movie_interactions[list(genres)] = 0

# %%
user_genre = user_genre.apply(norm_by_amout, axis=1)

# %%
for i, item in user_genre.iterrows():
  print(f'5 самых пополярных жанра для {item[2]} {item[0]} {item[1]}: {item[3:].sort_values(ascending=False)[:5].index.to_list()}')
# Out:
# 5 самых пополярных жанра для Ж age_18_24 income_0_20: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для М age_18_24 income_0_20: ['драмы', 'комедии', 'боевики', 'триллеры', 'приключения']
# 5 самых пополярных жанра для Ж age_18_24 income_150_inf: ['драмы', 'комедии', 'документальное', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_18_24 income_150_inf: ['драмы', 'приключения', 'семейное', 'мелодрамы', 'документальное']
# 5 самых пополярных жанра для Ж age_18_24 income_20_40: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для М age_18_24 income_20_40: ['драмы', 'комедии', 'боевики', 'триллеры', 'приключения']
# 5 самых пополярных жанра для Ж age_18_24 income_40_60: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для М age_18_24 income_40_60: ['драмы', 'комедии', 'боевики', 'триллеры', 'приключения']
# 5 самых пополярных жанра для Ж age_18_24 income_60_90: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_18_24 income_60_90: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_18_24 income_90_150: ['драмы', 'триллеры', 'комедии', 'мелодрамы', 'детективы']
# 5 самых пополярных жанра для М age_18_24 income_90_150: ['комедии', 'драмы', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для Ж age_25_34 income_0_20: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_25_34 income_0_20: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_25_34 income_150_inf: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_25_34 income_150_inf: ['драмы', 'комедии', 'приключения', 'триллеры', 'боевики']
# 5 самых пополярных жанра для Ж age_25_34 income_20_40: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_25_34 income_20_40: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_25_34 income_40_60: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_25_34 income_40_60: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_25_34 income_60_90: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_25_34 income_60_90: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_25_34 income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_25_34 income_90_150: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для Ж age_35_44 income_0_20: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_35_44 income_0_20: ['драмы', 'триллеры', 'боевики', 'комедии', 'приключения']
# 5 самых пополярных жанра для Ж age_35_44 income_150_inf: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_35_44 income_150_inf: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для Ж age_35_44 income_20_40: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_35_44 income_20_40: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_35_44 income_40_60: ['драмы', 'комедии', 'триллеры', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для М age_35_44 income_40_60: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_35_44 income_60_90: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_35_44 income_60_90: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_35_44 income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_35_44 income_90_150: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для Ж age_45_54 income_0_20: ['драмы', 'триллеры', 'комедии', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_0_20: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_45_54 income_150_inf: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_150_inf: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для Ж age_45_54 income_20_40: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_20_40: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_45_54 income_40_60: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_40_60: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_45_54 income_60_90: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_60_90: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_45_54 income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_45_54 income_90_150: ['драмы', 'комедии', 'триллеры', 'приключения', 'боевики']
# 5 самых пополярных жанра для Ж age_55_64 income_0_20: ['драмы', 'триллеры', 'комедии', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_55_64 income_0_20: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_55_64 income_150_inf: ['триллеры', 'драмы', 'детективы', 'документальное', 'мелодрамы']
# 5 самых пополярных жанра для М age_55_64 income_150_inf: ['драмы', 'триллеры', 'комедии', 'приключения', 'мелодрамы']
# 5 самых пополярных жанра для Ж age_55_64 income_20_40: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_55_64 income_20_40: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_55_64 income_40_60: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'боевики']
# 5 самых пополярных жанра для М age_55_64 income_40_60: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_55_64 income_60_90: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_55_64 income_60_90: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_55_64 income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'детективы']
# 5 самых пополярных жанра для М age_55_64 income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для Ж age_65_inf income_0_20: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_65_inf income_0_20: ['драмы', 'триллеры', 'комедии', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_65_inf income_150_inf: ['драмы', 'мелодрамы', 'комедии', 'триллеры', 'детективы']
# 5 самых пополярных жанра для М age_65_inf income_150_inf: ['драмы', 'триллеры', 'комедии', 'детективы', 'боевики']
# 5 самых пополярных жанра для Ж age_65_inf income_20_40: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_65_inf income_20_40: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_65_inf income_40_60: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_65_inf income_40_60: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_65_inf income_60_90: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'приключения']
# 5 самых пополярных жанра для М age_65_inf income_60_90: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
# 5 самых пополярных жанра для Ж age_65_inf income_90_150: ['драмы', 'комедии', 'триллеры', 'мелодрамы', 'детективы']
# 5 самых пополярных жанра для М age_65_inf income_90_150: ['драмы', 'комедии', 'триллеры', 'боевики', 'приключения']
